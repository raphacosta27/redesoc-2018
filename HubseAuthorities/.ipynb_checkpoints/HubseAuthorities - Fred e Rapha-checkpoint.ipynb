# %%
import socnet as sn
import networkx as nx
import numpy as np
from pprint import pprint
import scipy.stats as ss
import math

# %%
g = sn.load_graph('./one-mode.gml')
sn.graph_width = 720
sn.graph_height = 480

sn.node_size = 10
sn.node_color = (255, 255, 255)

sn.edge_width = 1
sn.edge_color = (192, 192, 192)
sn.node_label_position = 'top center'
sn.show_graph(g, nlab=True)
# Out:
# /Users/fredcurti/redesoc/redesoc-2018/HubseAuthorities/socnet.py:59: RuntimeWarning:
#
# divide by zero encountered in double_scalars
#
# /Users/fredcurti/redesoc/redesoc-2018/HubseAuthorities/socnet.py:187: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /Users/fredcurti/redesoc/redesoc-2018/HubseAuthorities/socnet.py:188: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /Users/fredcurti/redesoc/redesoc-2018/HubseAuthorities/socnet.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /Users/fredcurti/redesoc/redesoc-2018/HubseAuthorities/socnet.py:190: RuntimeWarning:
#
# invalid value encountered in double_scalars
# <div id="4b36a2d3-f7c1-4ace-badd-48c0c76d23ee" style="height: 480px; width: 720px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("4b36a2d3-f7c1-4ace-badd-48c0c76d23ee", [{"hoverinfo": "none", "line": {"color": "rgb(192, 192, 192)", "width": 1}, "mode": "lines", "x": [0.7116003337492663, 0.5001478598901247, null, 0.5080335097609266, 0.5142721201874647, null, 0.5080335097609266, 0.5156355169659663, null, 0.7116003337492663, 0.5313479156716413, null, 0.5392208573518178, 0.5454153508541979, null, 0.5392208573518178, 0.5468446765080434, null, 0.7116003337492663, 1.0, null, 0.9921797808570897, 0.9861541001954996, null, 0.9921797808570897, 0.9844796856187211, null, 0.7126943153793217, 0.6120647688213255, null, 0.6195060986564869, 0.6274612615854981, null, 0.5448027299041128, 0.6109707871912702, null, 0.6054173686384959, 0.6033130576168768, null, 0.6054173686384959, 0.5977745130985289, null, 0.39263929524535457, 0.5313479156716413, null, 0.5271611370039495, 0.5202114594254812, null, 0.5271611370039495, 0.5267623266838959, null, 0.39263929524535457, 0.0, null, 0.005961591448569536, 0.013760197792700057, null, 0.005961591448569536, 0.0086265624971978, null, 0.39263929524535457, 0.7116003337492663, null, 0.7047373780727033, 0.6967317428788151, null, 0.7047373780727033, 0.7006973928170349, null, 0.39263929524535457, 0.4681433108650431, null, 0.4646371423129039, 0.4581059272748277, null, 0.4646371423129039, 0.4650144525901684, null, 0.39263929524535457, 0.5208377276246053, null, 0.5128588222826929, 0.5062097481730259, null, 0.5128588222826929, 0.5055036000102872, null, 0.39402803116256485, 0.5079743763501173, null, 0.5015405705112119, 0.4981841742624134, null, 0.39263929524535457, 0.3658861556338169, null, 0.3688082475598152, 0.36779562570433466, null, 0.3688082475598152, 0.37494962325228937, null, 0.39263929524535457, 0.34020627534581016, null, 0.3449370518736291, 0.35218925342273594, null, 0.3449370518736291, 0.34598814429455066, null, 0.39263929524535457, 0.47383227046749654, null, 0.4704389299629815, 0.463980927675038, null, 0.4704389299629815, 0.4709410593442876, null, 0.34020627534581016, 0.3658861556338169, null, 0.364440380021211, 0.35939309192863045, null, 0.364440380021211, 0.3669500931817329, null, 0.5736054953436214, 0.6003813487048099, null, 0.5964322439351444, 0.5896239864634227, null, 0.5964322439351444, 0.5963091704449931, null, 0.5736054953436214, 0.4681433108650431, null, 0.4760678413769746, 0.48245356885251267, null, 0.4760678413769746, 0.48359097347831503, null, 0.5736054953436214, 0.5208377276246053, null, 0.5234779298162381, 0.5294219505238913, null, 0.5234779298162381, 0.5221678999150683, null, 0.5736054953436214, 0.47383227046749654, null, 0.48140952623119493, 0.48680987964050804, null, 0.48140952623119493, 0.48930850787229185, null, 0.5736054953436214, 0.6109707871912702, null, 0.6079844545927056, 0.6017989180826182, null, 0.6079844545927056, 0.6089284842777827, null, 0.5736054953436214, 0.7116003337492663, null, 0.7041174435030735, 0.6961767491280294, null, 0.7041174435030735, 0.6989244298929206, null, 0.3902847278948833, 0.47383227046749654, null, 0.46849999603694453, 0.460953049613695, null, 0.46849999603694453, 0.4666879203492614, null, null, null, null, null, null, null, 0.533471736763127, 0.5208377276246053, null, 0.5218974170430737, 0.5190195734907129, null, 0.5218974170430737, 0.5266351905047695, null, 0.47383227046749654, 0.6003813487048099, null, 0.5924102184251809, 0.5850235299259776, null, 0.5924102184251809, 0.585806257060467, null, 0.47383227046749654, 0.3658861556338169, null, 0.3716199780415477, 0.3793353180261938, null, 0.3716199780415477, 0.37396844317290345, null, null, null, null, null, null, null, 0.47383227046749654, 0.5313479156716413, null, 0.5254381323242067, 0.5176576010505635, null, 0.5254381323242067, 0.5228460179773323, null, 0.529849 ...

# %%
nodes = []
for k, v in dict(g.in_degree()).items():
    g.nodes[k]['in_degree'] = v
    nodes.append(g.nodes[k])
    
sorted(nodes, key= lambda x: x['in_degree'])
# Out:
# [{'label': 'Joao',
#   'color': (255, 255, 255),
#   'pos': (0.5736054953436214, 0.24754587464953556),
#   'in_degree': 0},
#  {'label': 'Paulo',
#   'color': (255, 255, 255),
#   'pos': (0.47255195209322887, 0.29196847490063643),
#   'in_degree': 0},
#  {'label': 'Ale',
#   'color': (255, 255, 255),
#   'pos': (0.647079498487631, 0.06591004570770366),
#   'in_degree': 0},
#  {'label': 'Pedro',
#   'color': (255, 255, 255),
#   'pos': (0.48140941931537806, 0.24405595437267555),
#   'in_degree': 0},
#  {'label': 'Tirta',
#   'color': (255, 255, 255),
#   'pos': (0.4955618507793142, 0.37073167224729386),
#   'in_degree': 0},
#  {'label': 'Jean',
#   'color': (255, 255, 255),
#   'pos': (0.5448027299041128, 0.0),
#   'in_degree': 1},
#  {'label': 'Bruna',
#   'color': (255, 255, 255),
#   'pos': (0.39263929524535457, 0.46070073351732654),
#   'in_degree': 1},
#  {'label': 'Carlos',
#   'color': (255, 255, 255),
#   'pos': (0.533471736763127, 0.6236219507508087),
#   'in_degree': 1},
#  {'label': 'Leo',
#   'color': (255, 255, 255),
#   'pos': (0.34020627534581016, 0.5703271148665214),
#   'in_degree': 2},
#  {'label': 'Gabs',
#   'color': (255, 255, 255),
#   'pos': (0.6284082305174891, 0.2805276003486342),
#   'in_degree': 2},
#  {'label': 'Elisa',
#   'color': (255, 255, 255),
#   'pos': (0.0, 1.0),
#   'in_degree': 2},
#  {'label': 'Sabrina',
#   'color': (255, 255, 255),
#   'pos': (0.5426474514234293, 0.2404829174372115),
#   'in_degree': 2},
#  {'label': 'Rios',
#   'color': (255, 255, 255),
#   'pos': (1.0, 0.26521776495572424),
#   'in_degree': 2},
#  {'label': 'Martim',
#   'color': (255, 255, 255),
#   'pos': (0.52452146250243, 0.22988660375259395),
#   'in_degree': 2},
#  {'label': 'Rapha',
#   'color': (255, 255, 255),
#   'pos': (0.3902847278948833, 0.33839163630970176),
#   'in_degree': 3},
#  {'label': 'Antonio',
#   'color': (255, 255, 255),
#   'pos': (0.5208377276246053, 0.47879781331566695),
#   'in_degree': 3},
#  {'label': 'Isa',
#   'color': (255, 255, 255),
#   'pos': (0.5001478598901247, 0.10840951100883209),
#   'in_degree': 3},
#  {'label': 'Rachel',
#   'color': (255, 255, 255),
#   'pos': (0.7116003337492663, 0.166723239432771),
#   'in_degree': 5},
#  {'label': 'Vitoria',
#   'color': (255, 255, 255),
#   'pos': (0.5065856404329071, 0.3313308524089531),
#   'in_degree': 5},
#  {'label': 'Chen',
#   'color': (255, 255, 255),
#   'pos': (0.6003813487048099, 0.1752470403251211),
#   'in_degree': 6},
#  {'label': 'Fred',
#   'color': (255, 255, 255),
#   'pos': (0.47383227046749654, 0.1950679113061719),
#   'in_degree': 7},
#  {'label': 'Toyama',
#   'color': (255, 255, 255),
#   'pos': (0.5313479156716413, 0.11452588163501372),
#   'in_degree': 7},
#  {'label': 'Forba',
#   'color': (255, 255, 255),
#   'pos': (0.4681433108650431, 0.22340174930003182),
#   'in_degree': 7},
#  {'label': 'Graicer',
#   'color': (255, 255, 255),
#   'pos': (0.3658861556338169, 0.3562280056295227),
#   'in_degree': 10},
#  {'label': 'Hugo',
#   'color': (255, 255, 255),
#   'pos': (0.6109707871912702, 0.10525843146600328),
#   'in_degree': 12}]

# %%
g2 = sn.load_graph('./two-mode.gml')
generos = ['Samba', 'MPB', 'Rap Nacional', 'Opera', 'Rock classico', 'Jazz', 'Pop', 'K-Pop', 'J-Pop', 'Pagode', 'Metal', 'Indie Rock', 'Funk', 'Sertanejo', 'Eletronica', 'Pop Rock', 'Disco']

# two_mode = {}
# soma = 0

# Calcula in degrees dos generos
for k, indeg in dict(g2.in_degree()).items():
    if g2.nodes[k]['label'] in generos:
        g2.nodes[k]['is_genre'] = True
        g2.nodes[k]['indegree_ponderado'] = indeg
    else:
        g2.nodes[k]['is_genre'] = False
        g2.nodes[k]['outdegree_ponderado'] = 0

euclid_anterior = 0
euclid_atual = 0
delta = 1

while delta > 0.000001:
    vec = []
    # Calcula outdegree        
    for k, v in dict(g2.nodes).items():
        if not v['is_genre']:
            succ = list(g2.successors(k))
            for s in succ:
                g2.nodes[k]['outdegree_ponderado'] += g2.nodes[s]['indegree_ponderado']

    # Calcula indegree ponderado
    for k, v in dict(g2.nodes).items():
        if v['is_genre']:
            predec = list(g2.predecessors(k))
            for p in predec:
                g2.nodes[k]['indegree_ponderado'] += g2.nodes[p]['outdegree_ponderado']

    # Normalizar
    soma_in = sum([g2.nodes[x]['indegree_ponderado'] for x in g2.nodes if g2.nodes[x]['is_genre']])
    soma_out = sum([g2.nodes[x]['outdegree_ponderado'] for x in g2.nodes if not g2.nodes[x]['is_genre']])

    for k, v in dict(g2.nodes).items():
        if (v['is_genre']):
            g2.nodes[k]['indegree_ponderado'] /= soma_in
            vec.append(g2.nodes[k]['indegree_ponderado'])
        else:
            g2.nodes[k]['outdegree_ponderado'] /= soma_out
            vec.append(g2.nodes[k]['outdegree_ponderado'])
    
    euclid_atual = np.array(vec)
    euclid_atual = np.sum(euclid_atual**2)**0.5
    delta = abs(euclid_atual - euclid_anterior)
    euclid_anterior = euclid_atual

# %% [markdown]
# ## Hubs

# %%
hubs = list(reversed(sorted([g2.nodes[x] for x in g2.nodes if not g2.nodes[x]['is_genre']], key=lambda x: x['outdegree_ponderado'])))
hubs
# Out:
# [{'label': 'Forba',
#   'color': (255, 255, 255),
#   'pos': (0.5402014803763217, 0.5348612719817443),
#   'is_genre': False,
#   'outdegree_ponderado': 0.09457695040590426},
#  {'label': 'Jean',
#   'color': (255, 255, 255),
#   'pos': (0.48164943113911324, 0.4925922137900236),
#   'is_genre': False,
#   'outdegree_ponderado': 0.06976807569750428},
#  {'label': 'Sabrina',
#   'color': (255, 255, 255),
#   'pos': (0.41083387752410605, 0.5952563482881227),
#   'is_genre': False,
#   'outdegree_ponderado': 0.06845074980707899},
#  {'label': 'Toyama',
#   'color': (255, 255, 255),
#   'pos': (0.5295270976417384, 0.4702694885450192),
#   'is_genre': False,
#   'outdegree_ponderado': 0.05998733471247563},
#  {'label': 'Rachel',
#   'color': (255, 255, 255),
#   'pos': (0.5156160103760824, 0.6260697090693957),
#   'is_genre': False,
#   'outdegree_ponderado': 0.05404076765751253},
#  {'label': 'Vitoria',
#   'color': (255, 255, 255),
#   'pos': (0.41807532607117215, 0.5172499259709218),
#   'is_genre': False,
#   'outdegree_ponderado': 0.05374476636202175},
#  {'label': 'Hugo',
#   'color': (255, 255, 255),
#   'pos': (0.5118851184547636, 0.5881110631554555),
#   'is_genre': False,
#   'outdegree_ponderado': 0.051297512289265726},
#  {'label': 'Isa',
#   'color': (255, 255, 255),
#   'pos': (0.48311250522620836, 0.6247915179406756),
#   'is_genre': False,
#   'outdegree_ponderado': 0.050524660640416816},
#  {'label': 'Graicer',
#   'color': (255, 255, 255),
#   'pos': (0.47301070947885343, 0.46956491381969917),
#   'is_genre': False,
#   'outdegree_ponderado': 0.04723974395057163},
#  {'label': 'Joao',
#   'color': (255, 255, 255),
#   'pos': (0.561437578391381, 0.5598933626298894),
#   'is_genre': False,
#   'outdegree_ponderado': 0.04671934985942606},
#  {'label': 'Fred',
#   'color': (255, 255, 255),
#   'pos': (0.5767601812534581, 0.4453769660158047),
#   'is_genre': False,
#   'outdegree_ponderado': 0.0444191537727633},
#  {'label': 'Chen',
#   'color': (255, 255, 255),
#   'pos': (0.5532979008602976, 0.5704806268580294),
#   'is_genre': False,
#   'outdegree_ponderado': 0.04399605317137955},
#  {'label': 'Pedro',
#   'color': (255, 255, 255),
#   'pos': (0.22147815632274462, 0.562383938006928),
#   'is_genre': False,
#   'outdegree_ponderado': 0.04199038158921065},
#  {'label': 'Martim',
#   'color': (255, 255, 255),
#   'pos': (0.3779871733731403, 0.7277988683855354),
#   'is_genre': False,
#   'outdegree_ponderado': 0.04097677898963952},
#  {'label': 'Gabs',
#   'color': (255, 255, 255),
#   'pos': (0.5947103274584001, 0.6317088849979985),
#   'is_genre': False,
#   'outdegree_ponderado': 0.03859748313531624},
#  {'label': 'Rapha',
#   'color': (255, 255, 255),
#   'pos': (0.5977528317142491, 0.6336113019495535),
#   'is_genre': False,
#   'outdegree_ponderado': 0.03859748313531623},
#  {'label': 'Ale',
#   'color': (255, 255, 255),
#   'pos': (0.46360021200925844, 0.40118884720538794),
#   'is_genre': False,
#   'outdegree_ponderado': 0.03836571723281062},
#  {'label': 'Bruna',
#   'color': (255, 255, 255),
#   'pos': (0.5963875992106559, 0.5231435503424432),
#   'is_genre': False,
#   'outdegree_ponderado': 0.030139848930587753},
#  {'label': 'Antonio',
#   'color': (255, 255, 255),
#   'pos': (0.6887016822564016, 0.5813909662627906),
#   'is_genre': False,
#   'outdegree_ponderado': 0.02427777270079677},
#  {'label': 'Paulo',
#   'color': (255, 255, 255),
#   'pos': (0.5010142035709176, 0.3642108777324203),
#   'is_genre': False,
#   'outdegree_ponderado': 0.021206437224686087},
#  {'label': 'Carlos',
#   'color': (255, 255, 255),
#   'pos': (0.24963797297791776, 0.8213253637471519),
#   'is_genre': False,
#   'outdegree_ponderado': 0.0204772378356011},
#  {'label': 'Elisa',
#   'color': (255, 255, 255),
#   'pos': (0.26975103505819154, 0.6597691099665678),
#   'is_genre': False,
#   'outdegree_ponderado': 0.015443284522196295},
#  {'label': 'Leo',
#   'color': (255, 255, 255),
#   'pos': (0.7388080027256692, 0.1362362392149731),
#   'is_genre': False,
#   'outdegree_ponderado': 0.005162456377518067}]

# %% [markdown]
# ## Authorities

# %%
# Authorities
auths = list(reversed(sorted([g2.nodes[x] for x in g2.nodes if g2.nodes[x]['is_genre']], key=lambda x: x['indegree_ponderado'])))
auths
# Out:
# [{'label': 'Eletronica',
#   'color': (255, 255, 255),
#   'pos': (0.0, 0.6405261717703029),
#   'is_genre': True,
#   'indegree_ponderado': 0.12792875764859404},
#  {'label': 'Rock classico',
#   'color': (255, 255, 255),
#   'pos': (0.32499297381178166, 0.08871139951357755),
#   'is_genre': True,
#   'indegree_ponderado': 0.08027758814996976},
#  {'label': 'Pop Rock',
#   'color': (255, 255, 255),
#   'pos': (0.04060828089357525, 0.31834144778301743),
#   'is_genre': True,
#   'indegree_ponderado': 0.07817693860604079},
#  {'label': 'Pop',
#   'color': (255, 255, 255),
#   'pos': (0.5008429659470405, 1.0),
#   'is_genre': True,
#   'indegree_ponderado': 0.07446041825185795},
#  {'label': 'Pagode',
#   'color': (255, 255, 255),
#   'pos': (0.9430513617024534, 0.16139063486557248),
#   'is_genre': True,
#   'indegree_ponderado': 0.07205255698074242},
#  {'label': 'Rap Nacional',
#   'color': (255, 255, 255),
#   'pos': (0.8001811375184348, 0.9039430928637863),
#   'is_genre': True,
#   'indegree_ponderado': 0.06778848912149975},
#  {'label': 'Indie Rock',
#   'color': (255, 255, 255),
#   'pos': (0.37225008907127055, 0.9673558522341403),
#   'is_genre': True,
#   'indegree_ponderado': 0.0645019950101209},
#  {'label': 'Disco',
#   'color': (255, 255, 255),
#   'pos': (0.19490312750587002, 0.8952151383408988),
#   'is_genre': True,
#   'indegree_ponderado': 0.0641441137114565},
#  {'label': 'Sertanejo',
#   'color': (255, 255, 255),
#   'pos': (0.8085080471453938, 0.8401133598437103),
#   'is_genre': True,
#   'indegree_ponderado': 0.05706094039643187},
#  {'label': 'Funk',
#   'color': (255, 255, 255),
#   'pos': (0.6449632693576026, 0.9737199153568895),
#   'is_genre': True,
#   'indegree_ponderado': 0.056639663261550316},
#  {'label': 'MPB',
#   'color': (255, 255, 255),
#   'pos': (0.46968985757799137, 0.014998293557114963),
#   'is_genre': True,
#   'indegree_ponderado': 0.054712174703384915},
#  {'label': 'Metal',
#   'color': (255, 255, 255),
#   'pos': (1.0, 0.5749295514037865),
#   'is_genre': True,
#   'indegree_ponderado': 0.05115166960543785},
#  {'label': 'J-Pop',
#   'color': (255, 255, 255),
#   'pos': (0.79960420440799, 0.037006694193778576),
#   'is_genre': True,
#   'indegree_ponderado': 0.05102635512626961},
#  {'label': 'Jazz',
#   'color': (255, 255, 255),
#   'pos': (0.986954220193956, 0.365565170329124),
#   'is_genre': True,
#   'indegree_ponderado': 0.04320457430327421},
#  {'label': 'Samba',
#   'color': (255, 255, 255),
#   'pos': (0.9359902468781556, 0.7820492939220285),
#   'is_genre': True,
#   'indegree_ponderado': 0.025960907741566383},
#  {'label': 'K-Pop',
#   'color': (255, 255, 255),
#   'pos': (0.08955849191456584, 0.7355697308953958),
#   'is_genre': True,
#   'indegree_ponderado': 0.022331835703965266},
#  {'label': 'Opera',
#   'color': (255, 255, 255),
#   'pos': (0.6181574758805347, 0.0),
#   'is_genre': True,
#   'indegree_ponderado': 0.00858102167783752}]

# %% [markdown]
# ## Hubs e Authorities com peso

# %%
g3 = sn.load_graph('./one-mode.gml')
for n in g3.nodes:
    g3.nodes[n]['weight_received_votes'] = 0
    g3.nodes[n]['received_votes'] = len(list(g3.predecessors(n)))
    g3.nodes[n]['vote_weight'] = 1 / (len(list(g3.successors(n)))) if len(list(g3.successors(n))) != 0 else 0

for n in g3.nodes:
    pessoa = g3.nodes[n]
    sucessores = g3.successors(n)
    for s in sucessores:
        g3.nodes[s]['weight_received_votes'] += pessoa['received_votes'] * pessoa['vote_weight']

# %%
for node in g3.nodes:
    print(g3.nodes[node])
# Out:
# {'label': 'Rachel', 'color': (255, 255, 255), 'pos': (0.1658495250601886, 0.14063816189089615), 'weight_received_votes': 4.711111111111111, 'received_votes': 5, 'vote_weight': 0.25}
# {'label': 'Jean', 'color': (255, 255, 255), 'pos': (0.2549241432229581, 0.0), 'weight_received_votes': 0.0, 'received_votes': 1, 'vote_weight': 1.0}
# {'label': 'Bruna', 'color': (255, 255, 255), 'pos': (0.474239777209346, 0.44731878184589674), 'weight_received_votes': 1.25, 'received_votes': 1, 'vote_weight': 0.1111111111111111}
# {'label': 'Leo', 'color': (255, 255, 255), 'pos': (0.29960572543858294, 0.4473312955077083), 'weight_received_votes': 0.1111111111111111, 'received_votes': 2, 'vote_weight': 1.0}
# {'label': 'Joao', 'color': (255, 255, 255), 'pos': (0.3162113348127247, 0.18696867294150138), 'weight_received_votes': 0, 'received_votes': 0, 'vote_weight': 0.16666666666666666}
# {'label': 'Rapha', 'color': (255, 255, 255), 'pos': (0.37892532420684166, 0.3177146710521094), 'weight_received_votes': 1.5999999999999999, 'received_votes': 3, 'vote_weight': 1.0}
# {'label': 'Carlos', 'color': (255, 255, 255), 'pos': (0.5372005310228829, 0.4071642092292908), 'weight_received_votes': 0.5, 'received_votes': 1, 'vote_weight': 0.5}
# {'label': 'Fred', 'color': (255, 255, 255), 'pos': (0.3165179803990102, 0.23533335972352365), 'weight_received_votes': 7.561111111111111, 'received_votes': 7, 'vote_weight': 0.25}
# {'label': 'Toyama', 'color': (255, 255, 255), 'pos': (0.24048656252397724, 0.15514113245856678), 'weight_received_votes': 5.111111111111112, 'received_votes': 7, 'vote_weight': 0.5}
# {'label': 'Vitoria', 'color': (255, 255, 255), 'pos': (0.36758095544327457, 0.2772730071799749), 'weight_received_votes': 4.761111111111111, 'received_votes': 5, 'vote_weight': 0.25}
# {'label': 'Hugo', 'color': (255, 255, 255), 'pos': (0.2364067522875377, 0.09218591180715859), 'weight_received_votes': 15.25, 'received_votes': 12, 'vote_weight': 0.3333333333333333}
# {'label': 'Gabs', 'color': (255, 255, 255), 'pos': (0.2057667009879726, 0.23472141351147416), 'weight_received_votes': 0.2, 'received_votes': 2, 'vote_weight': 0.2}
# {'label': 'Elisa', 'color': (255, 255, 255), 'pos': (1.0, 1.0), 'weight_received_votes': 2.111111111111111, 'received_votes': 2, 'vote_weight': 1.0}
# {'label': 'Paulo', 'color': (255, 255, 255), 'pos': (0.3017387141443374, 0.21535605462989), 'weight_received_votes': 0, 'received_votes': 0, 'vote_weight': 0.25}
# {'label': 'Sabrina', 'color': (255, 255, 255), 'pos': (0.2604574295257539, 0.2130858105708382), 'weight_received_votes': 3.25, 'received_votes': 2, 'vote_weight': 0.2}
# {'label': 'Forba', 'color': (255, 255, 255), 'pos': (0.2901474296347533, 0.24067199533079503), 'weight_received_votes': 9.81111111111111, 'received_votes': 7, 'vote_weight': 0.14285714285714285}
# {'label': 'Rios', 'color': (255, 255, 255), 'pos': (0.0, 0.18549068944194375), 'weight_received_votes': 1.65, 'received_votes': 2, 'vote_weight': 0}
# {'label': 'Ale', 'color': (255, 255, 255), 'pos': (0.36037125917381835, 0.05893293400058624), 'weight_received_votes': 0, 'received_votes': 0, 'vote_weight': 1.0}
# {'label': 'Graicer', 'color': (255, 255, 255), 'pos': (0.303002395786204, 0.3463879102934912), 'weight_received_votes': 10.86111111111111, 'received_votes': 10, 'vote_weight': 0.5}
# {'label': 'Antonio', 'color': (255, 255, 255), 'pos': (0.4537938438581499, 0.3025274853407285), 'weight_received_votes': 0.6111111111111112, 'received_votes': 3, 'vote_weight': 1.0}
# {'label': 'Martim', 'color': (255, 255, 255), 'pos': (0.27579886959103445, 0.21494190887520365), 'weight_received_votes': 1.2, 'received_votes': 2, 'vote_weight': 0.1}
# {'label': 'Pedro', 'color': (255, 255, 255), 'pos': (0.24616959249537781, 0.24159945154879497), 'weight_received_votes': 0, 'received_votes': 0, 'vote_weight': 0.3333333333333333}
# {'label': 'Isa', 'color': (255, 255, 255), 'pos': (0.3217328037032988, 0.1330251483133287), 'weight_received_votes': 5.45, 'received_votes': 3, 'vote_weight': 0.5}
# {'label': 'Chen', 'color': (255, 255, 255), 'pos': (0.2779610219809431, 0.11612867354959962), 'weight_received_votes': 5.0, 'received_votes': 6, 'vote_weight': 0.3333333333333333}
# {'label': 'Tirta', 'color': (255, 255, 255), 'pos': (0.23218552103369547, 0.34376446195294613), 'weight_received_votes': 0, 'received_votes': 0, 'vote_weight': 0.5}

# %%
sorted_by_weight_received_votes = list(reversed(sorted([g3.nodes[x] for x in g3.nodes], key=lambda x: x['weight_received_votes'])))
sorted_by_weight_received_votes_names = [(x['label'], round(x['weight_received_votes'], 2)) for x in sorted_by_weight_received_votes]
sorted_by_weight_received_votes_names
# Out:
# [('Hugo', 15.25),
#  ('Graicer', 10.86),
#  ('Forba', 9.81),
#  ('Fred', 7.56),
#  ('Isa', 5.45),
#  ('Toyama', 5.11),
#  ('Chen', 5.0),
#  ('Vitoria', 4.76),
#  ('Rachel', 4.71),
#  ('Sabrina', 3.25),
#  ('Elisa', 2.11),
#  ('Rios', 1.65),
#  ('Rapha', 1.6),
#  ('Bruna', 1.25),
#  ('Martim', 1.2),
#  ('Antonio', 0.61),
#  ('Carlos', 0.5),
#  ('Gabs', 0.2),
#  ('Leo', 0.11),
#  ('Tirta', 0),
#  ('Pedro', 0),
#  ('Ale', 0),
#  ('Paulo', 0),
#  ('Joao', 0),
#  ('Jean', 0.0)]

# %%
def get_node_by_name(name):
    return list(filter(lambda x: x['label'] == name, sorted_by_weight_received_votes))[0] or False

# %%
g4 = sn.load_graph('./two-mode.gml')
generos = ['Samba', 'MPB', 'Rap Nacional', 'Opera', 'Rock classico', 'Jazz', 'Pop', 'K-Pop', 'J-Pop', 'Pagode', 'Metal', 'Indie Rock', 'Funk', 'Sertanejo', 'Eletronica', 'Pop Rock', 'Disco']

# Calcula in degrees dos generos
for k, v in dict(g4.nodes).items():
    if g4.nodes[k]['label'] in generos:
        g4.nodes[k]['is_genre'] = True
        g4.nodes[k]['indegree_ponderado'] = 0
        predecessors = g4.predecessors(k)
        for p in predecessors:
            pred = get_node_by_name(g4.nodes[p]['label'])
            pred_successors = len(list(g4.successors(p)))
            g4.nodes[k]['indegree_ponderado'] += pred['weight_received_votes'] / pred_successors
            
    else:
        g4.nodes[k]['is_genre'] = False
        g4.nodes[k]['outdegree_ponderado'] = 0

euclid_anterior = 0
euclid_atual = 0
delta = 1

while delta > 0.000001:
    vec = []
    # Calcula outdegree        
    for k, v in dict(g4.nodes).items():
        if not v['is_genre']:
            succ = list(g4.successors(k))
            for s in succ:
                g4.nodes[k]['outdegree_ponderado'] += g4.nodes[s]['indegree_ponderado']

    # Calcula indegree ponderado
    for k, v in dict(g4.nodes).items():
        if v['is_genre']:
            predec = list(g4.predecessors(k))
            for p in predec:
                pred_successors = len(list(g4.successors(p)))
                g4.nodes[k]['indegree_ponderado'] += g4.nodes[p]['outdegree_ponderado'] / pred_successors

    # Normalizar
    soma_in = sum([g4.nodes[x]['indegree_ponderado'] for x in g4.nodes if g4.nodes[x]['is_genre']])
    soma_out = sum([g4.nodes[x]['outdegree_ponderado'] for x in g4.nodes if not g4.nodes[x]['is_genre']])

    for k, v in dict(g4.nodes).items():
        if (v['is_genre']):
            g4.nodes[k]['indegree_ponderado'] /= soma_in
            vec.append(g4.nodes[k]['indegree_ponderado'])
        else:
            g4.nodes[k]['outdegree_ponderado'] /= soma_out
            vec.append(g4.nodes[k]['outdegree_ponderado'])
    
    euclid_atual = np.array(vec)
    euclid_atual = np.sum(euclid_atual**2)**0.5
    delta = abs(euclid_atual - euclid_anterior)
    euclid_anterior = euclid_atual

# %%
auths_weighted = list(reversed(sorted([g4.nodes[x] for x in g4.nodes if g4.nodes[x]['is_genre']], key=lambda x: x['indegree_ponderado'])))
print('   AUTHS            AUTHS_WEIGHTED\n')
for i in range(len(auths)):
    print(f'{i+1}  '[0:2], '{0: <16}'.format(auths[i]['label']), auths_weighted[i]['label'])
# Out:
#    AUTHS            AUTHS_WEIGHTED
#
# 1  Eletronica       Eletronica
# 2  Rock classico    Pop
# 3  Pop Rock         Pop Rock
# 4  Pop              Rock classico
# 5  Pagode           Rap Nacional
# 6  Rap Nacional     Pagode
# 7  Indie Rock       Funk
# 8  Disco            Sertanejo
# 9  Sertanejo        Disco
# 10 Funk             Indie Rock
# 11 MPB              Metal
# 12 Metal            MPB
# 13 J-Pop            J-Pop
# 14 Jazz             Jazz
# 15 Samba            Samba
# 16 K-Pop            K-Pop
# 17 Opera            Opera

# %%
hubs_weighted = list(reversed(sorted([g4.nodes[x] for x in g4.nodes if not g4.nodes[x]['is_genre']], key=lambda x: x['outdegree_ponderado'])))
print('   HUBS       HUBS_WEIGHTED\n')
for i in range(len(hubs)):
    print(f'{i+1}  '[0:2], '{0: <10}'.format(hubs[i]['label']), hubs_weighted[i]['label'])
# Out:
#    HUBS       HUBS_WEIGHTED
#
# 1  Forba      Forba
# 2  Jean       Sabrina
# 3  Sabrina    Jean
# 4  Toyama     Toyama
# 5  Rachel     Rachel
# 6  Vitoria    Vitoria
# 7  Hugo       Hugo
# 8  Isa        Isa
# 9  Graicer    Joao
# 10 Joao       Graicer
# 11 Fred       Martim
# 12 Chen       Chen
# 13 Pedro      Rapha
# 14 Martim     Gabs
# 15 Gabs       Fred
# 16 Rapha      Pedro
# 17 Ale        Ale
# 18 Bruna      Bruna
# 19 Antonio    Antonio
# 20 Paulo      Carlos
# 21 Carlos     Paulo
# 22 Elisa      Elisa
# 23 Leo        Leo

# %%
def get_id_from_label(label):
    for q in g.nodes:
        if (g.nodes[q]['label'] == label):
            return q

hubs_arr = [get_id_from_label(x['label']) for x in hubs]
hubs_w_arr = [get_id_from_label(x['label']) for x in hubs_weighted]
print(hubs_arr,'\n', hubs_w_arr)
ss.wilcoxon(hubs_arr, hubs_w_arr)
# Out:
# [15, 1, 14, 8, 0, 9, 10, 22, 18, 4, 7, 23, 21, 20, 11, 5, 17, 2, 19, 13, 6, 12, 3]
#  [15, 14, 1, 8, 0, 9, 10, 22, 4, 18, 20, 23, 5, 11, 7, 21, 17, 2, 19, 6, 13, 12, 3]
# WilcoxonResult(statistic=32.5, pvalue=0.9644181927329321)
